# %% [markdown]
# # Fundamentals of Data Analysis
# # Semester 2 Project 2018
# ### Student:    David O'Brien
# ### Student ID: G00364766
#
# ## Box Plots

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 1 - The Box Plot

# %% [markdown]
# In descriptive statistics, a box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles$^{2}$.  It was invented by John Tukey as a tool for exploratory data analysis to show the distributional summary based on points within the actual data set.  His idea was to be able to create a plot quickly using a 5 number statistical summary that would visualise the distribution of a data set. The image below shows the different parts of the box plot
# <img src="https://github.com/davidobrien1/fda-project/blob/master/boxplotdiagram.JPG?raw=true" width="300" height="300">
#
# From the image above, we can see that the box plot is based on a five number summary.  These are as follows:
# - The lower extreme - this is the least value in the data set
# - The lower fourth (First Quartile or 25th percentile) - this is a number for whiche 25% of the data is less than that number$^{15}$
# - Medain (Second Quartile) - this is the number that divides the set in half (the middle value)
# - Upper fourth (Third Quartile or 75th percentile) - this is a number for whiche 75% of the data is less than that number$^{14}$
# - The upper extreme (Maximum) - this is the greatest value in the data set
#
# The lines at the end of the box are called the upper and lower whiskers
#
# The term Interquartile Range is the difference between the upper quartile and the lower quartile$^{17}$
#
# An outlier is an observation that is numerically distant from the rest of the data. When reviewing a boxplot, an outlier is defined as a data point that is located outside the fences (“whiskers”) of the boxplot (e.g: outside 1.5 times the interquartile range above the upper quartile and bellow the lower quartile)$^{18}$.
#
# The plot does not give as much information as other plots (i.e. histogram) as to the distribution of the data set, but it is  a good means  for indicating if the data set is skewed or there are outliers.
#
# If we take for example the number set 1,2,3,8,10,16,20,25 Five Number summary would be as follows:
#
# Number | Title
# -------|-------
# 1| Lower extreme
# 2.5| Lower fourth (First Quartile)
# 18| Median (Second Quartile)
# 1| Upper fourth (Third Quartile)
# 25| Upper extreme (Maximum)

# %% [markdown]
# ## 2 - Demonstrate the use of the box plot

# %% [markdown]
# ### 2.1 - Summary Statistics

# %%
# load data set and add column headers
df = pd.read_csv("Data\iris.csv", names = ["sepal length", "sepal width", "petal length", "petal width", "class"])

# %%
df[0:5] # show the first five rows of data to confirm that the data has loaded correctly
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.median()
# Out:
# sepal length    5.80
# sepal width     3.00
# petal length    4.35
# petal width     1.30
# dtype: float64

# %%
# A summary of the main statistics are shown in the table below.
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### 2.2 - Creating box plots

# %%
# create box plot showing the variables sepal length, sepal width, petal length and petal width
df.boxplot(column=["sepal length","sepal width","petal length","petal width"])

# %% [markdown]
# The above chart shows the distribution of the four variables across the combined Iris classes.  From the plot, it is easy to compare the different variables.  The one variable that jumps out to me is the sepal width, where the box plot is comparatively short.  This suggests that the over sepal widths (across all classes) are very similar, except for some outliers.
#
# The box plot for the petal length is comparatively tall, suggesting that there is a large range between the petal sizes.
#
# The points noted above will be investigated further in more detail by plotting the Iris dataset by class.  This way, we will be able to compare the different variables and see if they are similar or otherwise

# %%
# group the box plot by class
df.groupby("class").boxplot(column=["sepal length","sepal width","petal length","petal width"], figsize=(12,8)) # figure size increased to make it legible sourced from https://github.com/pandas-dev/pandas/issues/11959
# Out:
# Iris-setosa             AxesSubplot(0.1,0.559091;0.363636x0.340909)
# Iris-versicolor    AxesSubplot(0.536364,0.559091;0.363636x0.340909)
# Iris-virginica              AxesSubplot(0.1,0.15;0.363636x0.340909)
# dtype: object

# %% [markdown]
# From the above plot, it can be seen the the sepal widths are very similar between the different Iris classes, particularly the Versicolor and Virginica.  The Setosa seems to have a longer sepal width than the others.
#
# The petal lengths appear to be the least similar variable between the Iris classes, nearly having three distinct ranges:
# - Setosa - 1 to 1.9
# - Versicolor - 3 to 5.1
# - Virginica - 4.5 to 6.9
#
# Lets look at the Sepal Width and Petal Length on there own individual graphs so the distribution can be seen a bit clearer.

# %%
# group the box plot by class and show sepal width only
df.groupby("class").boxplot(column=["sepal width"], figsize=(12,8))
# Out:
# Iris-setosa             AxesSubplot(0.1,0.559091;0.363636x0.340909)
# Iris-versicolor    AxesSubplot(0.536364,0.559091;0.363636x0.340909)
# Iris-virginica              AxesSubplot(0.1,0.15;0.363636x0.340909)
# dtype: object

# %%
# group the box plot by class and show petal length only.  This plot really emphasises the difference in petal length across the different classes of Iris flower
df.groupby("class").boxplot(column=["petal length"], figsize=(12,8))
# Out:
# Iris-setosa             AxesSubplot(0.1,0.559091;0.363636x0.340909)
# Iris-versicolor    AxesSubplot(0.536364,0.559091;0.363636x0.340909)
# Iris-virginica              AxesSubplot(0.1,0.15;0.363636x0.340909)
# dtype: object

# %% [markdown]
# The plots below group the data by class and by the different variables.  This is a useful graph for spotting any similariies or differences in the variables.

# %%
# create a box plot comparing each of the variables for the different classes
df.boxplot(by='class',figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000209E5171DD8>,
# ...
#       dtype=object)

# %% [markdown]
# Another approach to the box plot is view the values on the x axis instead of the y axis as demonstrated on the plots below.

# %%
# create a horizontal box plot comparing each of the variables for the different classes. Adapted from https://stackoverflow.com/questions/18500011/horizontal-box-plots-in-matplotlib-pandas
df.boxplot(by='class',figsize=(12,8),vert=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000209E5BA8940>,
# ...
#       dtype=object)

# %% [markdown]
# ## 3 - Compare Box plot to alternatives

# %% [markdown]
# ## 3.1 - Comparison to Histograms

# %% [markdown]
# The plot below shows the distribution of the sepal length across all classes of the Iris flower, using a box plot and a histogram.  From this we can see that the box plot is a simpler representation of the data.  We can see the max, min, median and different quartiles for the data set.  The histogram is able to show us the quantities of sepal length that fall into the different length bands - it is visually easier to obtain this information from the histogram.

# %%
# adapted from https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/
# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
sns.boxplot(df["sepal length"], ax=ax_box)
sns.distplot(df["sepal length"], ax=ax_hist)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## 3.2 - Comparison to Pair Plots

# %% [markdown]
# Below, I have created a pair plot that details pairwise relationships in the data set.  This plot shows a large amount of information on the one plot and is much more detailed than the box plot.  It uses both histograms and scatterplots to show the relationships between the different variables.  One main difference between scatterplots and box plots is that the scatterplot plots each individual data point on the graph.  Understanding this plot takes a bit more time in comparison to a boxplot, where you can see the main statistics relatively quickly.

# %%
# plot pairwise relationships in the dataset
sns.pairplot(df, hue="class")

# %% [markdown]
# ## 3.4 - Comparison to line graphs

# %% [markdown]
# From the line graphs below, we can see that each data point is plotted.  It shows the range of values for each of the variables for the different Iris classes.  It is a relatively simple graph that gives less descriptive information than the box plot.

# %%
# create a line plot of the data set
df.groupby("class").plot.line()
# Out:
# class
# Iris-setosa        AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-versicolor    AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-virginica     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ## References
#
# 1 - http://www.physics.csbsju.edu/stats/box2.html
#
# 2 - https://en.wikipedia.org/wiki/Box_plot
#
# 3 - https://archive.ics.uci.edu/ml/datasets/iris
#
# 4 - https://stats.stackexchange.com/questions/369393/whats-the-history-of-box-plots-and-how-did-the-box-and-whiskers-design-evolv
#
# 5 - https://www150.statcan.gc.ca/n1/edu/power-pouvoir/ch12/5214889-eng.htm
#
# 6 - http://vita.had.co.nz/papers/boxplots.pdf
#
# 7 - http://informationandvisualization.de/blog/box-plot
#
# 8 - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html
#
# 9 - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.boxplot.html
#
# 10 - https://github.com/pandas-dev/pandas/issues/11959
#
# 11 - https://matplotlib.org/gallery/lines_bars_and_markers/bar_stacked.html
#
# 12 - https://stackoverflow.com/questions/18500011/horizontal-box-plots-in-matplotlib-pandas
#
# 13 - https://chartio.com/resources/tutorials/what-is-a-box-plot/
#
# 14 - http://www.mathwords.com/t/third_quartile.htm
#
# 15 - http://www.mathwords.com/f/first_quartile.htm
#
# 16 - https://www.ck12.org/statistics/box-and-whisker-plots/lesson/Box-and-Whisker-Plots-MSM6/
#
# 17 - http://www.flinders.edu.au/slc_files/Documents/Red%20Guides/Box%20and%20Whisker%20Plots.pdf
#
# 18 - https://www.r-statistics.com/2011/01/how-to-label-all-the-outliers-in-a-boxplot/
#
# 19 - https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/
#
# 20 - https://www.wellbeingatschool.org.nz/information-sheet/understanding-and-interpreting-box-plots

# %% [markdown]
# # End
